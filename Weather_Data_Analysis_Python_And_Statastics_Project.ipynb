# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Music\Python\Python New Practice Files 2\data_clean.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3      C     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3      C     5    5  2010    56       S

# %%
df.tail(5)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
df.shape
# Out:
# (158, 10)

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
x=df["Ozone"].mean()
x
# Out:
# 41.583333333333336

# %%
y=df["Ozone"].median()
y
# Out:
# 30.5

# %%
a=df["Solar.R"].mean()
a
# Out:
# 185.40397350993376

# %%
b=df["Solar.R"].median()
b
# Out:
# 197.0

# %%
c=df["Weather"].mode()[0]
c
# Out:
# 'S'

# %%
df["Ozone"].fillna(round(df["Ozone"].mean(),1)).isnull().sum()
# Out:
# 0

# %%
df["Ozone"]=df["Ozone"].fillna(round(df["Ozone"].mean(),1))

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
df["Solar.R"]=df["Solar.R"].fillna(a)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
df["Weather"]=df["Weather"].fillna(c)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       0
# dtype: int64

# %%
def fill_null(x):
    for i in x.columns:
        if x[i].dtypes=="object":
            x[i]=x[i].fillna(x[i].mode()[0])
        elif x[i].dtypes != "object":
            x[i]=x[i].fillna(x[i].mean())

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       0
# dtype: int64

# %%
fill_null(df)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       0
# dtype: int64

# %%
df.rename({"Solar.R":"solar","Temp C":"temp"},axis=1,inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Ozone       solar  Wind temp Month  Day  Year  Temp Weather
# 0             1   41.0  190.000000   7.4   67     5    1  2010    67       S
# 1             2   36.0  118.000000   8.0   72     5    2  2010    72       C
# 2             3   12.0  149.000000  12.6   74     5    3  2010    74      PS
# 3             4   18.0  313.000000  11.5   62     5    4  2010    62       S
# 4             5   41.6  185.403974  14.3    C     5    5  2010    56       S
# ..          ...    ...         ...   ...  ...   ...  ...   ...   ...     ...
# 153         154   41.0  190.000000   7.4   67     5    1  2010    67       C
# 154         155   30.0  193.000000   6.9   70     9   26  2010    70      PS
# 155         156   41.6  145.000000  13.2   77     9   27  2010    77       S
# 156         157   14.0  191.000000  14.3   75     9   28  2010    75       S
# 157         158   18.0  131.000000   8.0   76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df
# Out:
#      Unnamed: 0  Ozone       solar  Wind temp Month  Day  Year  Temp Weather
# 0             1   41.0  190.000000   7.4   67     5    1  2010    67       S
# 1             2   36.0  118.000000   8.0   72     5    2  2010    72       C
# 2             3   12.0  149.000000  12.6   74     5    3  2010    74      PS
# 3             4   18.0  313.000000  11.5   62     5    4  2010    62       S
# 4             5   41.6  185.403974  14.3    C     5    5  2010    56       S
# ..          ...    ...         ...   ...  ...   ...  ...   ...   ...     ...
# 153         154   41.0  190.000000   7.4   67     5    1  2010    67       C
# 154         155   30.0  193.000000   6.9   70     9   26  2010    70      PS
# 155         156   41.6  145.000000  13.2   77     9   27  2010    77       S
# 156         157   14.0  191.000000  14.3   75     9   28  2010    75       S
# 157         158   18.0  131.000000   8.0   76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.drop(["Unnamed: 0","temp"],axis=1,inplace=True)

# %%
df
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 153   41.0  190.000000   7.4     5    1  2010    67       C
# 154   30.0  193.000000   6.9     9   26  2010    70      PS
# 155   41.6  145.000000  13.2     9   27  2010    77       S
# 156   14.0  191.000000  14.3     9   28  2010    75       S
# 157   18.0  131.000000   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df[df.duplicated]
# Out:
#      Ozone  solar  Wind Month  Day  Year  Temp Weather
# 156   14.0  191.0  14.3     9   28  2010    75       S

# %%
df=df.drop_duplicates()
df
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.000000  11.5     9   30  2010    68       S
# 153   41.0  190.000000   7.4     5    1  2010    67       C
# 154   30.0  193.000000   6.9     9   26  2010    70      PS
# 155   41.6  145.000000  13.2     9   27  2010    77       S
# 157   18.0  131.000000   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Histogram

# %%
x=df["Ozone"].mean()
x
# Out:
# 41.763057324840766

# %%
y=df["Ozone"].median()
y
# Out:
# 41.6

# %%
z=df["Ozone"].mode()[0]
z
# Out:
# 41.6

# %%
plt.hist(df["Ozone"])
# Out:
# (array([28., 36., 59.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Ozone,color="b")
# Out:
# (array([28., 36., 59.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Ozone,color="red")
# Out:
# (array([28., 36., 59.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Ozone,color="r",width=7)
# Out:
# (array([28., 36., 59.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("OZONE VALUES")
plt.ylabel("INDEX VALUES")
plt.title("INDEX VS OZONE")
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axhline(x)
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axvline(x)
plt.axvline(y)
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axvline(x,label=f"mean{x}")
plt.axvline(y)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axvline(x,label=f"mean{x}")
plt.axvline(y,label=f"median{y}")
plt.axvline(z,label=f"mode{z}")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axvline(x,label=f"mean{x}",color="y")
plt.axvline(y,label=f"median{y}",color="b")
plt.axvline(z,label=f"mode{z}",color="k")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.hist(df.Ozone,color="r",width=7)
plt.xlabel("INDEX VALUES")
plt.ylabel("OZONE VALUES")
plt.title("INDEX VS OZONE")
plt.axvline(x,label=f"mean{x}",color="y")
plt.axvline(y,label=f"median{y}",color="b")
plt.axvline(z,label=f"mode{z}",color="k")
plt.legend(loc="center")
plt.show()

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df.Ozone)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_924\171954935.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Ozone)
# <Axes: xlabel='Ozone', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
df.describe()
# Out:
#             Ozone      solar        Wind         Day    Year        Temp
# count  157.000000  157.00000  157.000000  157.000000   157.0  157.000000
# mean    41.763057  185.36833    9.929936   15.929936  2010.0   77.745223
# std     28.404503   86.99900    3.505188    8.974404     0.0    9.405334
# min      1.000000    7.00000    1.700000    1.000000  2010.0   56.000000
# 25%     21.000000  127.00000    7.400000    8.000000  2010.0   72.000000
# 50%     41.600000  193.00000    9.700000   16.000000  2010.0   79.000000
# 75%     45.000000  255.00000   11.500000   24.000000  2010.0   84.000000
# max    168.000000  334.00000   20.700000   31.000000  2010.0   97.000000

# %%
plt.boxplot(df.Ozone)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ccac76d6d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ccac76e790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ccab172310>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ccac76f7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ccabe84f50>],
#  'means': []}

# %%
df[df["Ozone"]<75]
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.000000  11.5     9   30  2010    68       S
# 153   41.0  190.000000   7.4     5    1  2010    67       C
# 154   30.0  193.000000   6.9     9   26  2010    70      PS
# 155   41.6  145.000000  13.2     9   27  2010    77       S
# 157   18.0  131.000000   8.0     9   29  2010    76       C
#
# [135 rows x 8 columns]

# %%
df=df[df["Ozone"]<75]

# %%
plt.boxplot(df["Ozone"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ccac8e2350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ccac8e3710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ccac8e1c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ccac8e8910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ccac8e33d0>],
#  'means': []}

# %%
df.reset_index(drop=True)
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 130   20.0  223.000000  11.5     9   30  2010    68       S
# 131   41.0  190.000000   7.4     5    1  2010    67       C
# 132   30.0  193.000000   6.9     9   26  2010    70      PS
# 133   41.6  145.000000  13.2     9   27  2010    77       S
# 134   18.0  131.000000   8.0     9   29  2010    76       C
#
# [135 rows x 8 columns]

# %%
df
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.000000  11.5     9   30  2010    68       S
# 153   41.0  190.000000   7.4     5    1  2010    67       C
# 154   30.0  193.000000   6.9     9   26  2010    70      PS
# 155   41.6  145.000000  13.2     9   27  2010    77       S
# 157   18.0  131.000000   8.0     9   29  2010    76       C
#
# [135 rows x 8 columns]

# %% [markdown]
# ## Displot

# %%
sns.displot(x="Ozone",data=df)

# %%
sns.displot(x="Ozone",data=df,kde="hist")

# %%
sns.displot(x="Ozone",data=df,kind="ecdf")

# %%
sns.displot(x="Ozone",data=df,kind="kde")

# %%
sns.displot(x="Ozone",data=df,kind="kde",hue="Day")

# %%
df["Weather"].value_counts()
# Out:
# S     55
# C     42
# PS    38
# Name: Weather, dtype: int64

# %%
df["Weather"].value_counts().plot()
# Out:
# <Axes: >

# %%
df["Weather"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Weather'>

# %%
df
# Out:
#      Ozone       solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.000000   7.4     5    1  2010    67       S
# 1     36.0  118.000000   8.0     5    2  2010    72       C
# 2     12.0  149.000000  12.6     5    3  2010    74      PS
# 3     18.0  313.000000  11.5     5    4  2010    62       S
# 4     41.6  185.403974  14.3     5    5  2010    56       S
# ..     ...         ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.000000  11.5     9   30  2010    68       S
# 153   41.0  190.000000   7.4     5    1  2010    67       C
# 154   30.0  193.000000   6.9     9   26  2010    70      PS
# 155   41.6  145.000000  13.2     9   27  2010    77       S
# 157   18.0  131.000000   8.0     9   29  2010    76       C
#
# [135 rows x 8 columns]

# %%
df.dtypes
# Out:
# Ozone      float64
# solar      float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df.groupby(by="Weather")["Temp"].sum()
# Out:
# Weather
# C     3186
# PS    2818
# S     4239
# Name: Temp, dtype: int64

# %%
df.groupby(by="Weather")["Temp"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='Temp'>

# %%
plt.pie(df.Ozone)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccac1899d0>,
# ...
#  [Text(1.0995301571960305, 0.03214705921966423, ''),
#   Text(1.0961102320723262, 0.09242488380491226, ''),
#   Text(1.0923064801345392, 0.12987129573579292, ''),
#   Text(1.0892793469187296, 0.15320086284452264, ''),
#   Text(1.0817889278440753, 0.19933066897486326, ''),
#   Text(1.07057131725075, 0.25273910397877536, ''),
#   Text(1.060676814757852, 0.2914870402524568, ''),
#   Text(1.0514750994219508, 0.3231100668434811, ''),
#   Text(1.0450614171407828, 0.3432879759090009, ''),
#   Text(1.0322721413344598, 0.38001871825578487, ''),
#   Text(1.0184888455388523, 0.4155483985204808, ''),
#   Text(1.011538653890752, 0.43219156827139243, ''),
#   Text(1.0030328756343383, 0.45158061339777433, ''),
#   Text(0.9948257479161055, 0.4693844173842605, ''),
#   Text(0.9838599027408982, 0.4919549692590477, ''),
#   Text(0.9723820604724683, 0.5142695095680058, ''),
#   Text(0.9542184406097965, 0.5472359341273271, ''),
# ...

# %%
df.head(1)
# Out:
#    Ozone  solar  Wind Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4     5    1  2010    67       S

# %%
df[["Ozone","solar","Wind","Temp"]]
# Out:
#      Ozone       solar  Wind  Temp
# 0     41.0  190.000000   7.4    67
# 1     36.0  118.000000   8.0    72
# 2     12.0  149.000000  12.6    74
# 3     18.0  313.000000  11.5    62
# 4     41.6  185.403974  14.3    56
# ..     ...         ...   ...   ...
# 152   20.0  223.000000  11.5    68
# 153   41.0  190.000000   7.4    67
# 154   30.0  193.000000   6.9    70
# 155   41.6  145.000000  13.2    77
# 157   18.0  131.000000   8.0    76
#
# [135 rows x 4 columns]

# %%
df[["Ozone","solar","Wind","Temp"]].nunique()
# Out:
# Ozone     49
# solar    103
# Wind      26
# Temp      36
# dtype: int64

# %%
data=df[["Ozone","solar","Wind","Temp"]].nunique()
data
# Out:
# Ozone     49
# solar    103
# Wind      26
# Temp      36
# dtype: int64

# %%
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccac7bac50>,
# ...
#  [Text(0.827467283731731, 0.724774374790963, ''),
#   Text(-1.080028838249943, 0.20865691588940682, ''),
#   Text(0.14491279174225621, -1.0904128955535448, ''),
#   Text(0.9499251174661478, -0.5546550921130404, '')])

# %%
plt.pie(data,autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccac2c3410>,
# ...
#  [Text(0.827467283731731, 0.724774374790963, ''),
#   Text(-1.080028838249943, 0.20865691588940682, ''),
#   Text(0.14491279174225621, -1.0904128955535448, ''),
#   Text(0.9499251174661478, -0.5546550921130404, '')],
#  [Text(0.45134579112639867, 0.39533147715870703, '22.90%'),
#   Text(-0.5891066390454234, 0.1138128632124037, '48.13%'),
#   Text(0.07904334095032156, -0.5947706703019334, '12.15%'),
#   Text(0.5181409731633533, -0.30253914115256747, '16.82%')])

# %%
plt.pie(data,autopct="%1.2f%%",labels=["Ozone","solar","Wind","Temp"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccac86c610>,
# ...
#  [Text(0.827467283731731, 0.724774374790963, 'Ozone'),
#   Text(-1.080028838249943, 0.20865691588940682, 'solar'),
#   Text(0.14491279174225621, -1.0904128955535448, 'Wind'),
#   Text(0.9499251174661478, -0.5546550921130404, 'Temp')],
#  [Text(0.45134579112639867, 0.39533147715870703, '22.90%'),
#   Text(-0.5891066390454234, 0.1138128632124037, '48.13%'),
#   Text(0.07904334095032156, -0.5947706703019334, '12.15%'),
#   Text(0.5181409731633533, -0.30253914115256747, '16.82%')])

# %%
plt.pie(data,autopct="%1.2f%%",labels=["Ozone","solar","Wind","Temp"])
plt.legend(loc="center",title="DATA POINTS")

# %%
plt.pie(data,autopct="%1.2f%%",labels=["Ozone","solar","Wind","Temp"],explode=(0,0.02,0,0))
plt.legend(loc="center",title="DATA POINTS")

# %%
plt.pie(data,autopct="%1.2f%%",labels=["Ozone","solar","Wind","Temp"],explode=(0,0.2,0,0),shadow=True)
plt.legend(loc="center",title="DATA POINTS")

# %%
plt.plot(df.Ozone
         )

# %%
sns.pairplot(df)
